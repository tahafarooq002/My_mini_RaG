# %%
from assistant.stt import listen
from assistant.tts import speak
from assistant.rag import answer_query

while True:
    query = input("You: ")
    if query.lower() in ["exit", "quit"]: break
    answer, sources = answer_query(query)
    print("Assistant:", answer)
    speak(answer)
# Out:
# You:  hello
# Assistant: Hello! How can I assist you today?

# %%
from assistant.rag1 import answer_query

query = "Who is the main character in Pride and Prejudice?"
answer, sources = answer_query(query)

print("Answer:", answer)
print("Sources:", [s["doc_id"] for s in sources])
